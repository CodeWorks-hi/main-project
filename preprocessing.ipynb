# %%
import pandas as pd

# %%
df = pd.read_excel("extra_data/raw/재고 관련/기업경기조사(전망)_01000513.xlsx")
df
# Out:
#          업종코드            BSI코드  2016/01  2016/02  2016/03  2016/04  2016/05  \
# 0       전 산 업         기업심리지수전망     92.5     92.7     93.7     95.3     99.1
# 1       전 산 업    기업심리지수전망(S.A)      NaN      NaN      NaN      NaN      NaN
# 2       전 산 업       업황전망BSI 1)     69.0     67.0     67.0     71.0     74.0
# 3       전 산 업       매출전망BSI 2)     77.0     79.0     80.0     81.0     85.0
# 4       전 산 업       수출전망BSI 2)      NaN      NaN      NaN      NaN      NaN
# ..        ...              ...      ...      ...      ...      ...      ...
# 165      서비스업      채산성전망BSI 6)     82.0     84.0     87.0     85.0     88.0
# 166      서비스업  원자재구입가격전망BSI 4)      NaN      NaN      NaN      NaN      NaN
# 167      서비스업   제품판매가격전망BSI 4)      NaN      NaN      NaN      NaN      NaN
# 168      서비스업     자금사정전망BSI 6)     85.0     85.0     85.0     86.0     88.0
# 169      서비스업     인력사정전망BSI 3)     86.0     91.0     89.0     88.0     89.0
#
# ...

# %%
df["업종코드"] = df["업종코드"].str.replace(" ", "")

# %%
df
# Out:
#      업종코드            BSI코드  2016/01  2016/02  2016/03  2016/04  2016/05  \
# 0     전산업         기업심리지수전망     92.5     92.7     93.7     95.3     99.1
# 1     전산업    기업심리지수전망(S.A)      NaN      NaN      NaN      NaN      NaN
# 2     전산업       업황전망BSI 1)     69.0     67.0     67.0     71.0     74.0
# 3     전산업       매출전망BSI 2)     77.0     79.0     80.0     81.0     85.0
# 4     전산업       수출전망BSI 2)      NaN      NaN      NaN      NaN      NaN
# ..    ...              ...      ...      ...      ...      ...      ...
# 165  서비스업      채산성전망BSI 6)     82.0     84.0     87.0     85.0     88.0
# 166  서비스업  원자재구입가격전망BSI 4)      NaN      NaN      NaN      NaN      NaN
# 167  서비스업   제품판매가격전망BSI 4)      NaN      NaN      NaN      NaN      NaN
# 168  서비스업     자금사정전망BSI 6)     85.0     85.0     85.0     86.0     88.0
# 169  서비스업     인력사정전망BSI 3)     86.0     91.0     89.0     88.0     89.0
#
#      2016/06  2016/07  2016/08  ...  2024/05  2024/06  2024/07  2024/08  \
# ...

# %%
df.columns = df.columns.str.replace("/", "-")

# %%
df
# Out:
#      업종코드            BSI코드  2016-01  2016-02  2016-03  2016-04  2016-05  \
# 0     전산업         기업심리지수전망     92.5     92.7     93.7     95.3     99.1
# 1     전산업    기업심리지수전망(S.A)      NaN      NaN      NaN      NaN      NaN
# 2     전산업       업황전망BSI 1)     69.0     67.0     67.0     71.0     74.0
# 3     전산업       매출전망BSI 2)     77.0     79.0     80.0     81.0     85.0
# 4     전산업       수출전망BSI 2)      NaN      NaN      NaN      NaN      NaN
# ..    ...              ...      ...      ...      ...      ...      ...
# 165  서비스업      채산성전망BSI 6)     82.0     84.0     87.0     85.0     88.0
# 166  서비스업  원자재구입가격전망BSI 4)      NaN      NaN      NaN      NaN      NaN
# 167  서비스업   제품판매가격전망BSI 4)      NaN      NaN      NaN      NaN      NaN
# 168  서비스업     자금사정전망BSI 6)     85.0     85.0     85.0     86.0     88.0
# 169  서비스업     인력사정전망BSI 3)     86.0     91.0     89.0     88.0     89.0
#
#      2016-06  2016-07  2016-08  ...  2024-05  2024-06  2024-07  2024-08  \
# ...

# %%
df.to_excel("extra_data/processed/재고 관련/기업경기조사(전망)_01000513.xlsx", index=False)
