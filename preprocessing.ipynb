# %%
import pandas as pd

# %%
df = pd.read_excel("extra_data/raw/소비 심리 관련/현재생활형편.xlsx")
df
# Out:
#           CSI분류코드  2016/01  2016/02  2016/03  2016/04  2016/05  2016/06  \
# 0              전체       90       90       91       91       91       91
# 1              남자       91       90       91       91       91       90
# 2              여자       89       87       93       88       91       91
# 3           40세미만       92       92       95       91       90       92
# 4          40-50세       91       91       90       92       92       90
# 5          50-60세       87       87       88       90       89       90
# 6          60-70세       92       87       91       91       90       90
# 7           70세이상       89       88       88       89       92       90
# 8           봉급생활자       92       93       94       94       92       93
# 9            자영업자       85       81       83       85       87       85
# 10             기타       89       86       88       86       88       88
# 11        100만원미만       80       78       79       77       79       83
# ...

# %%
df.columns = df.columns.str.replace("/", "-")

# %%
df
# Out:
#           CSI분류코드  2016-01  2016-02  2016-03  2016-04  2016-05  2016-06  \
# 0              전체       90       90       91       91       91       91
# 1              남자       91       90       91       91       91       90
# 2              여자       89       87       93       88       91       91
# 3           40세미만       92       92       95       91       90       92
# 4          40-50세       91       91       90       92       92       90
# 5          50-60세       87       87       88       90       89       90
# 6          60-70세       92       87       91       91       90       90
# 7           70세이상       89       88       88       89       92       90
# 8           봉급생활자       92       93       94       94       92       93
# 9            자영업자       85       81       83       85       87       85
# 10             기타       89       86       88       86       88       88
# 11        100만원미만       80       78       79       77       79       83
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# CSI분류코드    object
# 2016-01     int64
# 2016-02     int64
# 2016-03     int64
# 2016-04     int64
#             ...
# 2024-10     int64
# 2024-11     int64
# 2024-12     int64
# 2025-01     int64
# 2025-02     int64
# Length: 111, dtype: object

# %%
df.to_csv("extra_data/processed/소비 심리 관련/현재생활형편.csv", index=False)
