# %%
import pandas as pd
import os
import numpy as np

# %%
filename = os.path.join("extra_data", "processed", "경제 성장 관련", "GDP_GNI_real.csv")
filename = os.path.join("extra_data", "processed", "경제 성장 관련", "GDP_GNI_nom.csv")
df_1 = pd.read_csv(filename, encoding='utf-8')
df_2 = pd.read_csv(filename, encoding='utf-8')

# %%
df_1
# Out:
#                          계정항목     2016/Q1     2016/Q2     2016/Q3     2016/Q4  \
# 0                        농림어업    7,676.5     8,402.9     7,966.0     7,839.3
# 1                         광공업  125,644.6   126,994.4   124,019.7   129,885.4
# 2                          광업      535.5       527.8       596.8       563.6
# 3                         제조업  125,109.2   126,466.6   123,422.9   129,321.9
# 4                    음식료품 제조업    5,603.3     5,670.0     5,820.3     5,624.9
# 5               섬유 및 가죽제품 제조업    4,762.5     4,717.3     4,658.5     4,710.5
# 6            목재, 종이, 인쇄 및 복제업    3,521.6     3,639.6     3,783.4     3,627.7
# 7             코크스 및 석유정제품 제조업    3,448.6     3,764.0     4,096.6     4,023.5
# 8             화학물질 및 화학제품 제조업   20,358.5    21,386.1    20,840.0    20,423.4
# 9                 비금속광물제품 제조업    3,090.1     3,102.8     3,171.2     3,342.6
# 10                   1차금속 제조업    7,289.3     8,183.4     7,871.7     7,896.9
# ...

# %%
df_1 = df_raw.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df_1 = df_raw.T
#
# NameError: name 'df_raw' is not defined

# %%
df_1.shape == (len(columns), len(index))
# Out:
# False

# %%
df_1
# Out:
#                          계정항목     2016/Q1     2016/Q2     2016/Q3     2016/Q4  \
# 0                        농림어업    7,676.5     8,402.9     7,966.0     7,839.3
# 1                         광공업  125,644.6   126,994.4   124,019.7   129,885.4
# 2                          광업      535.5       527.8       596.8       563.6
# 3                         제조업  125,109.2   126,466.6   123,422.9   129,321.9
# 4                    음식료품 제조업    5,603.3     5,670.0     5,820.3     5,624.9
# 5               섬유 및 가죽제품 제조업    4,762.5     4,717.3     4,658.5     4,710.5
# 6            목재, 종이, 인쇄 및 복제업    3,521.6     3,639.6     3,783.4     3,627.7
# 7             코크스 및 석유정제품 제조업    3,448.6     3,764.0     4,096.6     4,023.5
# 8             화학물질 및 화학제품 제조업   20,358.5    21,386.1    20,840.0    20,423.4
# 9                 비금속광물제품 제조업    3,090.1     3,102.8     3,171.2     3,342.6
# 10                   1차금속 제조업    7,289.3     8,183.4     7,871.7     7,896.9
# ...

# %%
# 1. 컬럼 설정
columns = [
    '2016/Q1','2016/Q2','2016/Q3','2016/Q4','2017/Q1','2017/Q2','2017/Q3','2017/Q4',
    '2018/Q1','2018/Q2','2018/Q3','2018/Q4','2019/Q1','2019/Q2','2019/Q3','2019/Q4',
    '2020/Q1','2020/Q2','2020/Q3','2020/Q4','2021/Q1','2021/Q2','2021/Q3','2021/Q4',
    '2022/Q1','2022/Q2','2022/Q3','2022/Q4','2023/Q1','2023/Q2','2023/Q3','2023/Q4',
    '2024/Q1','2024/Q2','2024/Q3','2024/Q4'
]


index = [
    '농림어업',
    '광공업',
    '  광업',
    '  제조업',
    '    음식료품 제조업',
    '    섬유 및 가죽제품 제조업',
    '    목재, 종이, 인쇄 및 복제업',
    '    코크스 및 석유정제품 제조업',
    '    화학물질 및 화학제품 제조업',
    '    비금속광물제품 제조업',
    '1차금속 제조업',
    '    금속가공제품 제조업',
    '    컴퓨터, 전자 및 광학기기 제조업',
    '    전기장비 제조업',
    '    기계 및 장비 제조업',
    '    운송장비 제조업',
    '    기타 제조업 및 산업용 장비 수리업',
    '전기, 가스 및 수도사업',
    '  전기업',
    '  가스, 증기 및 공기조절 공급업',
    '  수도, 하수 및 폐기물 처리, 원료 재생업',
    '건설업',
    '  건물건설 및 건축보수업',
    '    주거용 건물 건설업',
    '    비주거용 건물 건설업',
    '    건축보수업',
    '  토목건설업',
    '서비스업',
    '  도소매 및 숙박음식업',
    '    도소매업',
    '    숙박 및 음식점업',
    '  운수업',
    '  금융 및 보험업',
    '  부동산업',
    '  정보통신업',
    '    통신업',
    '    출판, 방송, 영상, 정보서비스',
    '  사업서비스업',
    '    전문, 과학 및 기술관련 서비스업',
    '    사업지원 서비스업',
    '  공공행정, 국방 및 사회보장',
    '  교육서비스업',
    '  의료, 보건업 및 사회복지서비스업',
    '  문화 및 기타 서비스업',
    '    예술, 스포츠 및 여가관련 서비스업',
    '    기타 서비스업',
    '총부가가치(기초가격)',
    '순생산물세',
    '국내총생산(시장가격, GDP)',
    '교역조건 변화를 반영한 실질무역손익',
    '국내총소득(GDI)',
    '국외순수취요소소득',
    '국민총소득(GNI)'
]
df_2 = pd.DataFrame(index = index)

# %%
df_2
# Out:
#                          계정항목     2016/Q1     2016/Q2     2016/Q3     2016/Q4  \
# 0                        농림어업    7,676.5     8,402.9     7,966.0     7,839.3
# 1                         광공업  125,644.6   126,994.4   124,019.7   129,885.4
# 2                          광업      535.5       527.8       596.8       563.6
# 3                         제조업  125,109.2   126,466.6   123,422.9   129,321.9
# 4                    음식료품 제조업    5,603.3     5,670.0     5,820.3     5,624.9
# 5               섬유 및 가죽제품 제조업    4,762.5     4,717.3     4,658.5     4,710.5
# 6            목재, 종이, 인쇄 및 복제업    3,521.6     3,639.6     3,783.4     3,627.7
# 7             코크스 및 석유정제품 제조업    3,448.6     3,764.0     4,096.6     4,023.5
# 8             화학물질 및 화학제품 제조업   20,358.5    21,386.1    20,840.0    20,423.4
# 9                 비금속광물제품 제조업    3,090.1     3,102.8     3,171.2     3,342.6
# 10                   1차금속 제조업    7,289.3     8,183.4     7,871.7     7,896.9
# ...
